# %%
#THIS IS THE FIRST CELL
print("Hello, world!")

# %%
from graph_display import GraphDisplay

# Create and display the graph
graph_display = GraphDisplay()
graph_display.build_ontology_graph()

# Add your ontology elements
graph_display.add_class("Person", "Person")
graph_display.add_class("Organization", "Organization")
graph_display.add_property("works_for", "Person", "Organization", "works for")

# Just display the graph (not dashboard)
graph_display.display_graph()
# Out:
# GraphWidget(layout=Layout(height='1500px', width='100%'))
